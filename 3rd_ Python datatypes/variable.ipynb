# %%
5
6
11
'testing'
5**1
43*1
45**45
33/3
12//32
''' this is demonstration of multi line comment   '''
""" this is my description of the code"""
4%4
45%3
'hello'"3rd_ Python datatypes"
#this is single line comment
"wlecome to the world of python'
# Out:
#   Cell In[71], line 16
#     "wlecome to the world of python'
#     ^
# SyntaxError: unterminated string literal (detected at line 16)

# %% [markdown]
# # python variable declaration

# %%
v=12
print(v)

_v=133  
print(_v)
# Out:
# 12
# 133

# %%
_v=122
_v

#1v=12
#1v
# Out:
# 122

# %%
#v2=12
#v2
$d=12
$d
# Out:
#   Cell In[39], line 3
#     $d=12
#     ^
# SyntaxError: invalid syntax

# %%
nit=12
NIT

test@=12
test@
# Out:
#   Cell In[44], line 5
#     test@
#          ^
# SyntaxError: invalid syntax

# %%
nit_=11
nit_
# Out:
# 11

# %%
_test=12
_test
# Out:
# 12

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
def=8
def
# Out:
#   Cell In[51], line 1
#     def=8
#        ^
# SyntaxError: invalid syntax

# %%
d1=True+2
isinstance(d1,float).bit_count
# Out:
# <function bool.bit_count()>

# %%
False/True
# Out:
# 0.0

# %%
from operator import rshift


demo='this is my string'

demo.rjust(40,"-")
# Out:
# '-----------------------this is my string'

# %%
test='this is demo'
test[3:4]
# Out:
# 's'
