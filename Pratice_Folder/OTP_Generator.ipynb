# %% [markdown]
# # generate otp

# %%
import random

def generate_otp(length=4):
    """ Generate otp using specified length.."""
    digits='012345'
    otp=''.join(random.choice(digits) for _ in range(length))
    return otp


# example usags
otp_length=4

otp=generate_otp(otp_length)
print(f"Your otp is : {otp}")
# Out:
# Your otp is : 4124
