# %%
def good():
    print('this is the print class')


good()



def good():
    return 'return the good values'

good()


def add(a,b):
    return a+b

print(add(2,3))

def d(a,b):
    return a+b


d(1,2)


def wish():
   return 'demo'

def wish():
    return 'king'

def wish():
    return 'money'

def wish():
    return 'mumbai'

wish()
# Out:
# this is the print class
# 5
# 'mumbai'

# %%
def add(a,b):
    c=a+b
    print(c)

add(12,23)
# Out:
# 35

# %%
def add(a,b):
    c=a+b
    print(c)

result= add(12,23)
result

type(result)
# Out:
# 35
# NoneType

# %% [markdown]
# # return more than 1 value

# %%
def d1(a,b):
    c=a+b
    d=a-b
    return c,d
result=d1(12,34)
print(result)

type(result)
# Out:
# (46, -22)
# tuple

# %%
def wish():
    print('this is demo')

wish()



def add(a,b,c):
    d=a
    s=b
    f=c
    return d,s,f
q,w,r=add(12,23,4)
print(q,w,r)

def sub(w,e):
    f=w-e
    print(f)
r=sub(23,6) 
r   
type(r)


def fg(df,er):
    gh=df+er
    return gh
k=fg(34,56)
k
type(k)
# Out:
# this is demo
# 12 23 4
# 17
# int
