# %%
import streamlit as st

st.write('this is my first app')
# Out:
# 2026-09-22 18:41:19.534 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-22 18:41:19.805
# ...
#   command:
#
#     streamlit run c:\Users\Pramod\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-09-22 18:41:19.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-22 18:41:19.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
